# %%
# !pip install pandas
# !pip install matplotlib
# !pip install Pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("registre_cantines.csv", sep=";")
df
# Out:
# /tmp/ipykernel_13210/2893592969.py:1: DtypeWarning: Columns (2,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("registre_cantines.csv", sep=";")
#            id                                               name  \
# 0      108743                              résidence Henri Douet
# 1      108742                                  Ecole de La Force
# 2      108741  Multi-accueils de la Communauté de Communes Su...
# 3      108740  Direction Enfance Jeunesse Famille, centre soc...
# 4      108739                             CPAM des Côtes d'Armor
# ...       ...                                                ...
# 38506      16        Lycée professionnel agricole Félix Gaillard
# 38507      15                                    Tables Communes
# 38508      14                                  Cantine de Misson
# 38509      13                                      Paul Sabatier
# ...

# %%
df["production_type"].unique()
# Out:
# array(['site', 'site_cooked_elsewhere', 'central', 'central_serving', nan],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'name', 'siret', 'city', 'city_insee_code', 'postal_code', 'epci',
#        'epci_lib', 'department', 'department_lib', 'region', 'region_lib',
#        'economic_model', 'management_type', 'production_type',
#        'satellite_canteens_count', 'central_producer_siret', 'creation_date',
#        'daily_meal_count', 'yearly_meal_count', 'line_ministry',
#        'modification_date', 'logo', 'sectors', 'publication_status',
#        'declaration_donnees_2021', 'declaration_donnees_2022',
#        'declaration_donnees_2023_en_cours', 'active_on_ma_cantine'],
#       dtype='object')

# %%
df2 = df.groupby(by=["production_type", "economic_model"]).count()[["id"]].unstack("economic_model")
# df2.set_index("economic_model").unstack("economic_model").plot(kind="bar")
df2[("id", "private")] /= df2[("id", "private")].sum()
# df2"id,
# Out:
#                    id
# economic_model
# private           154
# public           1732
# private           331
# public           1119
# private          3662
# public          11510
# private          2798
# public          10191
